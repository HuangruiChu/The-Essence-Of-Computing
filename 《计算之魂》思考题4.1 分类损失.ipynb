# %% [markdown]
# Author: Huangrui Chu
#
# Bachelor: Duke Kunshan University
#
# Master: Yale University
#
# Reference Book: 《The Essence Of Computing》Author: Jun Wu
#
# Reference Blog: https://zhuanlan.zhihu.com/p/507630748 Author:鳄鱼

# %% [markdown]
# # 思考题 4.1
#
# 有两类模式A和B。如果A被识别为了B，损失是10；如果B被识别为了A，损失是1。这两类模式之间的边界应该如何划定？ 二星/五星

# %% [markdown]
# 很明显，A被判做是B后损失会更大，所有应该把分界线放的离B 稍微近一点，这样A被判为B的情况就少一些了。

# %% [markdown]
# 我们假定A为淡蓝色的点,B为红色的点。如下图所示，有两个分类的界限，蓝色虚线以及黑色实线。那么从损失来说，蓝色虚线不认黑色实线好。
#
# loss_of_blue=10
#
# loss_of_black=3

# %%
import numpy as np
import pylab as pl  # 绘图功能

# 创建 40 个点
np.random.seed(0) # 让每次运行程序生成的随机样本点不变
X = np.r_[np.random.randn(30, 2) - [2, 2], np.random.randn(20, 2) + [1.5, 1.5]]
# 两个类别 每类有 20 个点，Y 为 40 行 1 列的列向量
Y = [0] * 30 + [1] * 20



pl.scatter(X[:, 0], X[:, 1], c=Y, cmap=pl.cm.Paired)
pl.plot((0.5,0.5), (-4,3), 'k-')
pl.plot((0.1,0.1), (-4,3), 'b--')
pl.axis('tight')
pl.show()

# %% [markdown]
# 在我们训练神经网络的分类器的时候，设计loss函数可以给A更多的权重。
